# %% [markdown]
# <a href="https://colab.research.google.com/github/accarter/DS-Unit-1-Sprint-4-Build-1/blob/master/Unit_1_Build_Video_Game_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS Unit 1 Sprint 4 Build 1 - Video Game Sales

# %% [markdown]
# ## Data Exploration and Cleaning

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/accarter/portfolio/master/assets/vgsales.csv'
vg = pd.read_csv(url)
vg.head()
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %%
# remove Global_Sales column
vg = vg.drop('Global_Sales', axis=1)

# restructure DataFrame 
vg_tidy = pd.melt(vg, id_vars= vg.columns[:6], var_name="Region", value_name="Sales")

# rename regions
vg_tidy['Region'] = vg_tidy['Region'].replace({
    'NA_Sales': 'North America',
    'EU_Sales': 'Europe',
    'JP_Sales': 'Japan',
    'Other_Sales': 'Other'
})

vg_tidy.head()
# Out:
#    Rank                      Name Platform  ...  Publisher         Region  Sales
# 0     1                Wii Sports      Wii  ...   Nintendo  North America  41.49
# 1     2         Super Mario Bros.      NES  ...   Nintendo  North America  29.08
# 2     3            Mario Kart Wii      Wii  ...   Nintendo  North America  15.85
# 3     4         Wii Sports Resort      Wii  ...   Nintendo  North America  15.75
# 4     5  Pokemon Red/Pokemon Blue       GB  ...   Nintendo  North America  11.27
#
# [5 rows x 8 columns]

# %%
vg_tidy.shape
# Out:
# (66392, 8)

# %%
vg_tidy.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year         1084
# Genre           0
# Publisher     232
# Region          0
# Sales           0
# dtype: int64

# %%
vg_tidy.describe()
# Out:
#                Rank          Year         Sales
# count  66392.000000  65308.000000  66392.000000
# mean    8300.605254   2006.406443      0.134291
# std     4791.745667      5.828847      0.519930
# min        1.000000   1980.000000      0.000000
# 25%     4151.000000   2003.000000      0.000000
# 50%     8300.500000   2007.000000      0.010000
# 75%    12450.000000   2010.000000      0.090000
# max    16600.000000   2020.000000     41.490000

# %%
vg_tidy.describe(exclude='number')
# Out:
#                                Name Platform   Genre        Publisher Region
# count                         66392    66392   66392            66160  66392
# unique                        11493       31      12              578      4
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts  Japan
# freq                             48     8652   13264             5404  16598

# %% [markdown]
# ## Data Visualization

# %%
import plotly.graph_objects as go

genres = list(vg_tidy['Genre'].unique())

data = []
for region in vg_tidy['Region'].unique():
    y = [vg_tidy[(vg_tidy['Genre'] == genre) & (vg_tidy['Region'] == region)]['Sales'].sum() for genre in genres]
    data.append(go.Bar(name=region, x=genres, y=y, text=y))

fig = go.Figure(data=data)
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5ba892ea-0b94-4e9b-81fd-c85dbd797410" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ba892ea-0b94-4e9b-81fd-c85dbd797410")) {
#                     Plotly.newPlot(
#                         '5ba892ea-0b94-4e9b-81fd-c85dbd797410',
#                         [{"name": "North America", "text": ["683.35", "447.05", "359.41999999999996", "327.28", "123.78", "410.24", "582.6", "183.30999999999997", "877.83", "223.58999999999997", "105.80000000000001", "68.69999999999999"], "type": "bar", "x": ["Sports", "Platform", "Racing", "Role-Playing", "Puzzle", "Misc", "Shooter", "Simulation", "Action", "Fighting", "Adventure", "Strategy"], "y": [683.35, 447.05, 359.41999999999996, 327.28, 123.78, 410.24, 582.6, 183.30999999999997, 877.83, 223.58999999999997, 105.80000000000001, 68.69999999999999]}, {"name": "Europe", "text": ["376.85", "201.63000000000002", "238.39000000000001", "188.05999999999997", "50.779999999999994", "215.98000000000002", "313.27000000000004", "113.38000000000001", "525.0", "101.32000000000001", "64.13", "45.339999999999996"], "type": "bar", "x": ["Sports", "Platform", "Racing", "Role-Playing", "Puzzle", "Misc", "Shooter", "Simulation", "Action", "Fighting", "Adventure", "Strategy"], "y": [376.85, 201.63000000000002, 238.39000000000001, 188.05999999999997, 50.779999999999994, 215.98000000000002, 313.27000000000004, 113.38000000000001, 525.0, 101.32000000000001, 64.13, 45.339999999999996]}, {"name": "Japan", "text": ["135.37", "130.77", "56.68999999999999", "352.31", "57.309999999999995", "107.76", "38.28", "63.7", "159.95000000000002", "87.35000000000001", "52.07", "49.46000000000001"], "type": "bar", "x": ["Sports", "Platform", "Racing", "Role-Playing", "Puzzle", "Misc", "Shooter", "Simulation", "Action", "Fighting", "Adventure", "Strategy"], "y": [135.37, 130.77, 56.68999999999999, 352.31, 57.309999999999995, 107.76, 38.28, 63.7, 159.95000000000002, 87.35000000000001, 52.07, 49.46000000000001]}, {"name": "Other", "text": ["134.97", "51.589999999999996", "77.27000000000001", "59.61", "12.55", "75.32000000000001", "102.69", "31.519999999999996", "187.38000000000002", "36.68000000000001", "16.81", "11.359999999999998"], "type": "bar", "x": ["Sports", "Platform", "Racing", "Role-Playing", "Puzzle", "Misc", "Shooter", "Simulation", "Action", "Fighting", "Adventure", "Strategy"], "y": [134.97, 51.589999999999996, 77.27000000000001, 59.61, 12.55, 75.32000000000001, 102.69, 31.519999999999996, 187.38000000000002, 36.68000000000001, 16.81, 11.359999999999998]}],
#                         {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %%
vg_global = pd.DataFrame(vg_tidy.groupby(['Name', 'Year', 'Genre'])['Sales'].sum()).reset_index()

data = []

for genre in vg_tidy['Genre'].unique():
    vg_global_by_genre = vg_global[vg_global['Genre'] == genre]
    data.append(go.Scatter(x=vg_global_by_genre['Year'],
                           y=vg_global_by_genre['Sales'],
                           mode='markers',
                           name=genre,
                           text=vg_global_by_genre['Name']))
  
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="95da1714-29c3-4287-bc76-181d3a1c86db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95da1714-29c3-4287-bc76-181d3a1c86db")) {
#                     Plotly.newPlot(
#                         '95da1714-29c3-4287-bc76-181d3a1c86db',
#                         [{"mode": "markers", "name": "Sports", "text": ["'98 Koshien", "10 Minute Solution", "101-in-1 Sports Megamix", "101-in-1 Sports Party Megamix", "1080\u00b0: TenEighty Snowboarding", "2002 FIFA World Cup", "2010 FIFA World Cup South Africa", "2014 FIFA World Cup Brazil", "2Xtreme", "3D Baseball", "AMF Bowling 2004", "AMF Bowling Pinbusters!", "AMF Bowling Pinbusters!", "AMF Bowling World Lanes", "AMF Xtreme Bowling", "Academy of Champions: Soccer", "Active Health with Carol Vorderman", "Active Life Explorer", "Active Life: Extreme Challenge", "Active Life: Outdoor Challenge", "Actua Tennis", "Adidas Power Soccer", "Adidas Power Soccer 98", "After Hours Athletes", "Agassi Tennis Generation", "Aggressive Inline", "Airblade", "Alexi Lalas International Soccer", "Alien Monster Bowling League", "All Star Cheer Squad", "All Star Cheer Squad 2", "All Star Tennis 99", "All-Pro Football 2K8", "All-Star Baseball 2000", "All-Star Baseball 2001", "All-Star Baseball 2002", "All-Star Baseball 2003", "All-Star Baseball 2004", "All-Star Baseball 99", "American Bass Challenge", "Amped 2", "Amped 3", "Amped: Freestyle Snowboarding", "Angler's Club: Ultimate Bass Fishing 3D", "Animaniacs Ten Pin Alley", "Archer Maclean Presents: Pool Paradise", "Arena Football", "Ashes Cricket 2009", "Athens 2004", "BCFX: The Black College Football Xperience, The Doug Williams Edition", "BMX XXX", "Back At The Barnyard: Slop Bucket Games", "Backyard Baseball", "Backyard Baseball", "Backyard Baseball", "Backyard Baseball '09", "Backyard Baseball '10", "Backyard Baseball 2006", "Backyard Basketball", "Backyard Hockey", "Backyard Hockey", "Backyard NBA Basketball", "Backyard NBA Basketball", "Backyard NFL Football", "Backyard NFL Football", "Backyard NFL Football '08", "Backyard NFL Football '09", "Backyard NFL Football '10", "Backyard NFL Football 2006", "Backyard Skateboarding 2006", "Backyard Soccer", "Backyard Sports Football: Rookie Rush", "Backyard Sports: Sandlot Sluggers", "Ballblazer Champions", "Balls of Fury", "Banushi Life Game: Winner's Circle", "Barbie Horse Adventures: Blue Ribbon Race", "Barbie Horse Adventures: Riding Camp", "Barbie Horse Adventures: Wild Horse Rescue", "Barbie Super Sports", "Baseball", "Baseball", "Baseball Advance", "Baseball Blast!", "Bases Loaded '96: Double Header", "Basketball Hall of Fame Ultimate Hoops Challenge", "Bass Hunter 64", "Bass Landing", "Bass Pro Shops: The Hunt", "Bass Pro Shops: The Strike", "Bass Rise", "Bass Strike", "Bassmasters 2000", "Battle Dodge Ball", "Battle Soccer: Field no Hasha", "Beach Spikers: Virtua Beach Volleyball", "Beijing 2008", "Big Air", "Big Bass World Championship", "Big Beach Sports", "Big League Sports", "Big League Sports", "Big League Sports: Summer", "Big Mountain 2000", "Big Strike Bowling", "Billy's Boot Camp: Wii de Enjoy Diet!", "Black Bass with Blue Marlin", "Blast Lacrosse", "Blitz: Overtime", "Blitz: The League", "Blitz: The League", "Blitz: The League", "Blitz: The League II", "Blood Bowl", "Blood Bowl: Legendary Edition", "Bode Miller Alpine Skiing", "Bottom of the 9th", "Bottom of the 9th", "Bottom of the 9th '97", "Bottom of the 9th '99", "Boxing Fever", "Breeding Stud 2", "Brian Lara Cricket", "Brunswick Circuit Pro Bowling", "Brunswick Circuit Pro Bowling", "Brunswick Circuit Pro Bowling 2", "Brunswick Cosmic Bowling", "Brunswick Pro Bowling", "Brunswick Pro Bowling", "Brunswick Pro Bowling", "Buck Fever", "Burstrick: Wake Boarding!!", "Cabela's African Safari", "Cabela's Alaskan Adventure", "Cabela's Big Game Hunter", "Cabela's Big Game Hunter (2008)", "Cabela's Big Game Hunter 2005 Adventures", "Cabela's Big Game Hunter 2010", "Cabela's Big Game Hunter 2012", "Cabela's Big Game Hunter: Hunting Party", "Cabela's Big Game Hunter: Ultimate Challenge", "Cabela's Dangerous Hunts", "Cabela's Dangerous Hunts 2", "Cabela's Dangerous Hunts 2009", "Cabela's Dangerous Hunts 2011", "Cabela's Dangerous Hunts: Ultimate Challenge", "Cabela's Deer Hunt 2005 S ...

# %%
vg_00 = vg_tidy[(vg_tidy['Year'] >= 2000) & (vg_tidy['Year'] < 2010)]
G = vg_00.groupby(['Region', 'Genre'])['Sales']
vg_00_glob = G.sum().unstack(level=['Genre']).reset_index()
vg_00_glob.head()
# Out:
# Genre         Region  Action  Adventure  ...  Simulation  Sports  Strategy
# 0             Europe  235.80      31.00  ...       79.14  223.94     20.30
# 1              Japan   60.02      21.67  ...       26.86   60.37     20.91
# 2      North America  463.12      62.04  ...      136.86  433.84     32.91
# 3              Other   99.37       9.26  ...       23.16   87.16      5.72
#
# [4 rows x 13 columns]

# %%
import plotly.graph_objects as go
import numpy as np

data = []
for genre in vg_tidy['Genre'].unique():
    data.append(go.Bar( x=vg_00_glob['Region'], y=vg_00_glob[genre], name=genre))
    
fig = go.Figure(data=data)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="191e38ae-e87f-4582-ab4e-7964aa69613d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("191e38ae-e87f-4582-ab4e-7964aa69613d")) {
#                     Plotly.newPlot(
#                         '191e38ae-e87f-4582-ab4e-7964aa69613d',
#                         [{"name": "Sports", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [223.94000000000028, 60.37000000000002, 433.8399999999978, 87.16000000000118]}, {"name": "Platform", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [102.59000000000032, 39.46, 203.63000000000036, 31.260000000000186]}, {"name": "Racing", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [138.32999999999998, 21.070000000000025, 226.76000000000042, 54.29999999999989]}, {"name": "Role-Playing", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [81.27000000000017, 138.17000000000021, 171.1899999999999, 27.600000000000193]}, {"name": "Puzzle", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [33.71999999999996, 20.780000000000015, 55.640000000000036, 8.669999999999964]}, {"name": "Misc", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [131.94000000000017, 61.14000000000011, 242.93000000000043, 50.95999999999986]}, {"name": "Shooter", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [123.51000000000046, 9.23999999999998, 257.92999999999904, 43.709999999999965]}, {"name": "Simulation", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [79.1400000000002, 26.860000000000024, 136.86000000000013, 23.16000000000019]}, {"name": "Action", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [235.7999999999999, 60.02000000000001, 463.1199999999988, 99.37000000000153]}, {"name": "Fighting", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [54.640000000000065, 31.000000000000014, 122.06000000000002, 23.56000000000011]}, {"name": "Adventure", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [31.000000000000075, 21.67000000000007, 62.040000000000084, 9.259999999999954]}, {"name": "Strategy", "type": "bar", "x": ["Europe", "Japan", "North America", "Other"], "y": [20.300000000000075, 20.910000000000014, 32.90999999999996, 5.719999999999967]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ## Inferential Statistics

# %% [markdown]
# ### Comparison of average sales figures between all possible combinations of genres using two-sample independent t-tests

# %%
import scipy.stats as stats

def ttest_genres(genre1, genre2, alpha):
    def sales_for_genre(genre):
        return vg_tidy[vg_tidy['Genre'] == genre]['Sales']
    
    
    if genre1 == genre2: return ''
    
    pval = stats.ttest_ind(sales_for_genre(genre1),
                           sales_for_genre(genre2), 
                           nan_policy='omit')[1]
    
    if pval < alpha: return ''
    return '{:.2g}'.format(pval)

genres = list(vg_tidy['Genre'].unique())
ttest_dict = {genre1: [ttest_genres(genre1, genre2, 0.05) for genre2 in genres] for genre1 in genres}
ttest_dict['Genres']  = genres
pd.DataFrame(ttest_dict).set_index('Genres')
# Out:
#              Sports Platform Racing  ... Fighting Adventure Strategy
# Genres                               ...
# Sports                         0.67  ...     0.44
# Platform                             ...
# Racing         0.67                  ...     0.16
# Role-Playing   0.18            0.36  ...
# Puzzle                               ...
# Misc                                 ...    0.061
# Shooter                              ...
# Simulation                           ...
# Action         0.17                  ...     0.96
# Fighting       0.44            0.16  ...
# Adventure                            ...
# Strategy                             ...
#
# [12 rows x 12 columns]

# %% [markdown]
# ### Chi-square tests to determine relationship between tastes between all possible cominbations of regions

# %%
def chi2_region(df, region1, region2):
    table = pd.concat([
        df[df['Region'] == region1],
        df[df['Region'] == region2]
    ]).set_index('Region')
    
    chi2, pval, dof, expected = stats.chi2_contingency(table.iloc[:,1:])
    return '{:.2g}'.format(pval)

regions = list(vg_tidy['Region'].unique())
chi2_dict = {region1: [chi2_region(vg_00_glob, region1, region2) 
                       for region2 in regions] 
             for region1 in regions}
chi2_df = pd.DataFrame(chi2_dict)
chi2_df['Regions']  = regions
chi2_df = pd.DataFrame(chi2_df).set_index('Regions')
chi2_df
# Out:
#               North America Europe    Japan    Other
# Regions
# North America             1   0.84  6.4e-44     0.78
# Europe                 0.84      1    5e-36     0.94
# Japan               6.4e-44  5e-36        1  4.7e-23
# Other                  0.78   0.94  4.7e-23        1
